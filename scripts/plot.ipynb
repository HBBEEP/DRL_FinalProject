# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Read CSV file
df = pd.read_csv(r'C:\Users\peera\OneDrive\Documents\GitHub\DRL_FinalProject\output\DQN_policy_exp1_1024\train_log.csv')  # Replace with your actual file path

# Plot each column against the index
df[['loss']].plot()
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Metrics over Episodes')
plt.legend(title='Metrics')
plt.grid(True)
plt.tight_layout()
plt.show()
